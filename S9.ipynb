# %%
import torch
import torch.optim as optim
from torchvision import datasets, transforms
import torch.nn as nn
import torch.nn.functional as F

from model import Model
from get_device import *
from utils import *

# %pip install torchsummary
from torchsummary import summary


import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from Dataset import CIFAR10
batch_size = 32
cifar10 = CIFAR10(batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
cifar10.show_examples()

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

model1 = Model(skip= True, dropout= 0.01).to(device)
summary(model1, input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 16, 32, 32]             432
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#            Dropout-4           [-1, 16, 32, 32]               0
#          ConvLayer-5           [-1, 16, 32, 32]               0
#             Conv2d-6           [-1, 16, 32, 32]             144
#        BatchNorm2d-7           [-1, 16, 32, 32]              32
#               ReLU-8           [-1, 16, 32, 32]               0
#             Conv2d-9           [-1, 16, 32, 32]             256
#       BatchNorm2d-10           [-1, 16, 32, 32]              32
#              ReLU-11           [-1, 16, 32, 32]               0
#           Dropout-12           [-1, 16, 32, 32]               0
#         ConvLayer-13           [-1, 16, 32, 32]               0
# ...

# %%
model = Experiment(model1, cifar10, lr = 0.01)
model.execute(num_epochs= 40)
# Out:
# Epoch 1
# Train: Loss=1.8160 Batch_id=1562 Train_Accuracy=46.29: 100%|██████████| 1563/1563 [01:29<00:00, 17.50it/s]
# Test: Average loss: 1.0819, Test_Accuracy: 60.98
# Epoch 2
# Train: Loss=1.1760 Batch_id=1562 Train_Accuracy=59.88: 100%|██████████| 1563/1563 [01:28<00:00, 17.63it/s]
# Test: Average loss: 0.9200, Test_Accuracy: 67.50
# Epoch 3
# Train: Loss=0.5303 Batch_id=1562 Train_Accuracy=65.28: 100%|██████████| 1563/1563 [01:38<00:00, 15.90it/s]
# Test: Average loss: 0.8131, Test_Accuracy: 71.52
# Epoch 4
# Train: Loss=0.6630 Batch_id=1562 Train_Accuracy=68.34: 100%|██████████| 1563/1563 [01:33<00:00, 16.79it/s]
# Test: Average loss: 0.7409, Test_Accuracy: 74.13
# Epoch 5
# Train: Loss=1.2542 Batch_id=1562 Train_Accuracy=70.63: 100%|██████████| 1563/1563 [01:32<00:00, 16.90it/s]
# Test: Average loss: 0.7192, Test_Accuracy: 75.33
# Epoch 6
# Train: Loss=0.5710 Batch_id=1562 Train_Accuracy=72.54: 100%|██████████| 1563/1563 [01:34<00:00, 16.51it/s]
# ...

# %%
model.train.plot_stats()

# %%
model.test.plot_stats()
